# %%
import os
import numpy as np
from copy import deepcopy
from matplotlib import pyplot as plt
import pymatching
from types_cfg import *
from circuit_generators import *
from sampling_functions import *
from circuit_partition import *
from utilities_tf import *
from CNNModel import *
from BootstrapSampler import *
from custom_training import *


# Number of worker nodes
n_worker_nodes = 8

# Surface code specifications
d = 5
r = 5
kernel_size = 3

# Data types
binary_t, time_t, idx_t, packed_t = get_types(d, r, kernel_size)

# Error probabilities
p = 0.01
before_round_data_depolarization = p
after_reset_flip_probability = p
after_clifford_depolarization = p
before_measure_flip_probability = p

use_rotated_z = True
observable_type = "ZL" if use_rotated_z else "XL"

# Call signatures for functions that require types
call_group_det_bits_kxk = lambda det_bits_dxd, data_bits_dxd=None, d=d, r=r, k=kernel_size, use_rotated_z=use_rotated_z, binary_t=binary_t, idx_t=idx_t, make_translation_map=False: group_det_bits_kxk(det_bits_dxd, d, r, k, use_rotated_z, data_bits_dxd, binary_t, idx_t, make_translation_map)
call_split_measurements = lambda measurements, d=d, idx_t=idx_t: split_measurements(measurements, d, idx_t)
# Out:
# 2024-07-12 15:54:04.717908: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-12 15:54:04.718008: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-12 15:54:04.718018: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-12 15:54:04.723053: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Configure, check for any saved data, and make it if needed.

# %%
n_test = 5000000
n_train = 5000000
stim_sampler_seed = 12345
rnd_seed = 12345
n_samples = n_test + n_train

config_name = f"surface_code_d{d}_r{r}_k{kernel_size}_rRCNN_probaccdec"
saved_data_dir = f"saved_data/{config_name}/obs_{observable_type}_prob_{str(p).replace('.','p')}"
saved_data_dir = f"{saved_data_dir}_N_{n_samples}_seed_{stim_sampler_seed}"
os.makedirs(saved_data_dir, exist_ok=True)

config_data_name = f"surface_code_d{d}_r{r}_k{kernel_size}_rRCNN"
saved_sdata_dir = f"saved_data/{config_data_name}/obs_{observable_type}_prob_{str(p).replace('.','p')}"
saved_sdata_dir = f"{saved_sdata_dir}_N_{n_samples}_seed_{stim_sampler_seed}"
has_saved_data = os.path.exists(saved_sdata_dir)

decoders = ['pymatching']
test_circuit = get_builtin_circuit(
  "surface_code:rotated_memory_"+('z' if use_rotated_z else 'x'),
  distance=d,
  rounds=r,
  before_round_data_depolarization = before_round_data_depolarization,
  after_reset_flip_probability = after_reset_flip_probability,
  after_clifford_depolarization = after_clifford_depolarization,
  before_measure_flip_probability = before_measure_flip_probability
)
kernel_circuit = get_builtin_circuit(
  "surface_code:rotated_memory_"+('z' if use_rotated_z else 'x'),
  distance=kernel_size,
  rounds=r,
  before_round_data_depolarization = before_round_data_depolarization,
  after_reset_flip_probability = after_reset_flip_probability,
  after_clifford_depolarization = after_clifford_depolarization,
  before_measure_flip_probability = before_measure_flip_probability
)
projerr_circuit = CircuitWithProjectiveErrors(d, r, test_circuit, seed = stim_sampler_seed)
detector_error_model = test_circuit.detector_error_model(decompose_errors=True)

if not has_saved_data:
  measurements, det_evts, flips = projerr_circuit.sample(n_samples, binary_t = binary_t)
else:
  measurements = np.load(f"{saved_sdata_dir}/measurements.npy")
  det_evts = np.load(f"{saved_sdata_dir}/det_evts.npy")
  flips = np.load(f"{saved_sdata_dir}/flips.npy")

# %%
avg_flips = np.mean(flips, axis=0, dtype=np.float32)
print(f"Average flip rate for the full circuit: {avg_flips}")
# Out:
# Average flip rate for the full circuit: [0.1325141 0.2012585 0.2568247 0.3022833 0.3390904 0.3545189]

# %%
det_bits, _, _ = call_split_measurements(measurements)

# %%
# Make sure the data type is np.int32 below, not idx_t!
idxs_test, idxs_train = split_data(np.arange(n_samples, dtype=np.int32), test_size = n_test/n_samples, seed = rnd_seed, shuffle = False)

class_bits = flips[:, 1:]
features_det_bits = det_bits
features_det_evts = det_evts

print(class_bits.shape)
print(features_det_bits.shape)
print(features_det_evts.shape)
# Out:
# (10000000, 5)
# (10000000, 120)
# (10000000, 120)

# %%
def learning_rate_scheduler(epoch, lr):
  if epoch < 10:
    return 0.001*(10-epoch)
  elif epoch < 20:
    return lr * 0.9
  elif epoch < 30:
    return lr * 0.8
  else:
    return lr * 0.65

# %%
n_nodes = 100
model_dxd = FullRCNNModel(
  observable_type, d, kernel_size, r,
  [n_nodes for _ in range(2)],
  npol=2,
  stop_round = None,
  has_nonuniform_response = False,
  do_all_data_qubits = False,
  return_all_rounds = True,
  probability_accumulation_mode = FullRCNNModelEnums.prob_decoded_acc
)
loss_fcn = RCNNRecurrenceLoss(r, True)
metric_fcn = RCNNRecurrenceAccuracy(r, True)
model_dxd.compile(optimizer='adam', loss=loss_fcn, metrics=[metric_fcn])
model_dxd([ features_det_bits[0:1], features_det_evts[0:1] ])
model_dxd.summary()
# Out:
# 2024-07-12 15:54:15.634068: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-12 15:54:15.658843: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-12 15:54:15.659132: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-12 15:54:15.671059: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-12 15:54:15.671327: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-12 15:54:15.671534: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-12 15:54:15.731592: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-12 15:54:15.731863: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-12 15:54:15.732057: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-12 15:54:15.732179: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38660 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 4g.40gb, pci bus id: 0000:05:00.0, compute capability: 8.0
# Number of unique contributions: 13
# Total number of fractions: 28
# Total number of phases: 62
# Number of unique contributions: 13
# Total number of fractions: 28
# Total number of phases: 62
# Number of unique contributions: 13
# Total number of fractions: 28
# Total number of phases: 62
# Number of unique contributions: 13
# Total number of fractions: 28
# Total number of phases: 62
# 2024-07-12 15:54:17.144290: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Model: "full_rcnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rcnn_initial_state_kernel_  multiple                  8848
#  combiner (RCNNInitialState
#  KernelCombiner)
#
#  rcnn_lead_in_kernel_combin  multiple                  11870
#  er (RCNNLeadInKernelCombin
#  er)
#
#  rcnn_recurrence_kernel_com  multiple                  17938
#  biner (RCNNRecurrenceKerne
#  lCombiner)
#
#  rcnn_final_state_kernel_co  multiple                  18028
#  mbiner (RCNNFinalStateKern
#  elCombiner)
#
#  dense (Dense)               multiple                  2600
#
#  dense_1 (Dense)             multiple                  10100
#
#  dense_2 (Dense)             multiple                  101
#
# =================================================================
# Total params: 69485 (271.43 KB)
# Trainable params: 69485 (271.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
val_split = 0.2
n_epochs = 50
history = model_dxd.fit(
  x=[ features_det_bits[idxs_train], features_det_evts[idxs_train] ],
  y=class_bits[idxs_train],
  batch_size=10000,
  epochs=n_epochs, validation_split=val_split,
  callbacks=[
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    tf.keras.callbacks.LearningRateScheduler(learning_rate_scheduler)
  ]
)

flips_pred = model_dxd.predict(
  [ features_det_bits[idxs_test], features_det_evts[idxs_test] ],
  batch_size=10000
)
print(f"Inaccuracy of the final model on the test data: {(class_bits[idxs_test]!=(flips_pred>0.5).astype(binary_t)).astype(binary_t).sum(axis=0)/idxs_test.shape[0]}")
# Out:
# Epoch 1/50
# 2024-07-12 15:58:38.759231: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fe7080f59b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-12 15:58:38.759319: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100 80GB PCIe MIG 4g.40gb, Compute Capability 8.0
# 2024-07-12 15:58:38.763222: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-12 15:58:38.774639: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-07-12 15:58:38.858832: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 400/400 [==============================] - 501s 587ms/step - loss: 1.7717 - rcnn_recurrence_accuracy: 0.7861 - val_loss: 1.6508 - val_rcnn_recurrence_accuracy: 0.8086 - lr: 0.0100
# Epoch 2/50
# 400/400 [==============================] - 199s 497ms/step - loss: 1.6244 - rcnn_recurrence_accuracy: 0.8147 - val_loss: 1.6072 - val_rcnn_recurrence_accuracy: 0.8180 - lr: 0.0090
# Epoch 3/50
# 400/400 [==============================] - 199s 499ms/step - loss: 1.5985 - rcnn_recurrence_accuracy: 0.8202 - val_loss: 1.5933 - val_rcnn_recurrence_accuracy: 0.8209 - lr: 0.0080
# Epoch 4/50
# 400/400 [==============================] - 200s 499ms/step - loss: 1.5842 - rcnn_recurrence_accuracy: 0.8230 - val_loss: 1.5807 - val_rcnn_recurrence_accuracy: 0.8238 - lr: 0.0070
# Epoch 5/50
# 400/400 [==============================] - 199s 498ms/step - loss: 1.5745 - rcnn_recurrence_accuracy: 0.8252 - val_loss: 1.5757 - val_rcnn_recurrence_accuracy: 0.8249 - lr: 0.0060
# Epoch 6/50
# 400/400 [==============================] - 197s 493ms/step - loss: 1.5688 - rcnn_recurrence_accuracy: 0.8263 - val_loss: 1.5836 - val_rcnn_recurrence_accuracy: 0.8230 - lr: 0.0050
# Epoch 7/50
# 400/400 [==============================] - 199s 497ms/step - loss: 1.5646 - rcnn_recurrence_accuracy: 0.8271 - val_loss: 1.5649 - val_rcnn_recurrence_accuracy: 0.8273 - lr: 0.0040
# Epoch 8/50
# 400/400 [==============================] - 200s 499ms/step - loss: 1.5553 - rcnn_recurrence_accuracy: 0.8289 - val_loss: 1.5588 - val_rcnn_recurrence_accuracy: 0.8280 - lr: 0.0030
# Epoch 9/50
# 400/400 [==============================] - 197s 493ms/step - loss: 1.5493 - rcnn_recurrence_accuracy: 0.8299 - val_loss: 1.5541 - val_rcnn_recurrence_accuracy: 0.8290 - lr: 0.0020
# Epoch 10/50
# 400/400 [==============================] - 199s 498ms/step - loss: 1.5441 - rcnn_recurrence_accuracy: 0.8310 - val_loss: 1.5506 - val_rcnn_recurrence_accuracy: 0.8296 - lr: 0.0010
# Epoch 11/50
# 400/400 [==============================] - 199s 497ms/step - loss: 1.5420 - rcnn_recurrence_accuracy: 0.8314 - val_loss: 1.5490 - val_rcnn_recurrence_accuracy: 0.8299 - lr: 9.0000e-04
# Epoch 12/50
# 400/400 [==============================] - 201s 503ms/step - loss: 1.5405 - rcnn_recurrence_accuracy: 0.8317 - val_loss: 1.5487 - val_rcnn_recurrence_accuracy: 0.8300 - lr: 8.1000e-04
# Epoch 13/50
# 400/400 [==============================] - 199s 497ms/step - loss: 1.5394 - rcnn_recurrence_accuracy: 0.8320 - val_loss: 1.5478 - val_rcnn_recurrence_accuracy: 0.8303 - lr: 7.2900e-04
# Epoch 14/50
# 400/400 [==============================] - 198s 494ms/step - loss: 1.5383 - rcnn_recurrence_accuracy: 0.8322 - val_loss: 1.5476 - val_rcnn_recurrence_accuracy: 0.8304 - lr: 6.5610e-04
# Epoch 15/50
# 400/400 [==============================] - 201s 501ms/step - loss: 1.5373 - rcnn_recurrence_accuracy: 0.8324 - val_loss: 1.5463 - val_rcnn_recurrence_accuracy: 0.8307 - lr: 5.9049e-04
# Epoch 16/50
# 400/400 [==============================] - 199s 497ms/step - loss: 1.5363 - rcnn_recurrence_accuracy: 0.8327 - val_loss: 1.5457 - val_rcnn_recurrence_accuracy: 0.8305 - lr: 5.3144e-04
# Epoch 17/50
# 400/400 [==============================] - 199s 497ms/step - loss: 1.5355 - rcnn_recurrence_accuracy: 0.8328 - val_loss: 1.5456 - val_rcnn_recurrence_accuracy: 0.8307 - lr: 4.7830e-04
# Epoch 18/50
# 400/400 [==============================] - 199s 498ms/step - loss: 1.5348 - rcnn_recurrence_accuracy: 0.8329 - val_loss: 1.5449 - val_rcnn_recurrence_accuracy: 0.8309 - lr: 4.3047e-04
# Epoch 19/50
# 400/400 [==============================] - 199s 498ms/step - loss: 1.5342 - rcnn_recurrence_accuracy: 0.8331 - val_loss: 1.5445 - val_rcnn_recurrence_accuracy: 0.8309 - lr: 3.8742e-04
# Epoch 20/50
# 400/400 [==============================] - 198s 494ms/step - loss: 1.5337 - rcnn_recurrence_accuracy: 0.8332 - val_loss: 1.5443 - val_rcnn_recurrence_accuracy: 0.8310 - lr: 3.4868e-04
# Epoch 21/50
# 400/400 [==============================] - 198s 495ms/step - loss: 1.5328 - rcnn_recurrence_accuracy: 0.8334 - val_loss: 1.5438 - val_rcnn_recurrence_accuracy: 0.8310 - lr: 2.7894e-04
# Epoch 22/50
# 400/400 [==============================] - 199s 498ms/step - loss: 1.5322 - rcnn_recurrence_accuracy: 0.8335 - val_loss: 1.5436 - val_rcnn_recurrence_accuracy: 0.8311 - lr: 2.2315e-04
# Epoch 23/50
# 400/400 [==============================] - 198s 494ms/step - loss: 1.5317 - rcnn_recurrence_accuracy: 0.8336 - val_loss: 1.5436 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 1.7852e-04
# Epoch 24/50
# 400/400 [==============================] - 198s 495ms/step - loss: 1.5313 - rcnn_recurrence_accuracy: 0.8337 - val_loss: 1.5434 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 1.4282e-04
# Epoch 25/50
# 400/400 [==============================] - 199s 496ms/step - loss: 1.5310 - rcnn_recurrence_accuracy: 0.8338 - val_loss: 1.5434 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 1.1425e-04
# Epoch 26/50
# 400/400 [==============================] - 197s 494ms/step - loss: 1.5307 - rcnn_recurrence_accuracy: 0.8339 - val_loss: 1.5433 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 9.1404e-05
# Epoch 27/50
# 400/400 [==============================] - 197s 493ms/step - loss: 1.5305 - rcnn_recurrence_accuracy: 0.8339 - val_loss: 1.5432 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 7.3123e-05
# Epoch 28/50
# 400/400 [==============================] - 199s 497ms/step - loss: 1.5304 - rcnn_recurrence_accuracy: 0.8339 - val_loss: 1.5433 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 5.8499e-05
# Epoch 29/50
# 400/400 [==============================] - 198s 496ms/step - loss: 1.5302 - rcnn_recurrence_accuracy: 0.8340 - val_loss: 1.5432 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 4.6799e-05
# Epoch 30/50
# 400/400 [==============================] - 198s 494ms/step - loss: 1.5301 - rcnn_recurrence_accuracy: 0.8340 - val_loss: 1.5432 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 3.7439e-05
# Epoch 31/50
# 400/400 [==============================] - 199s 497ms/step - loss: 1.5300 - rcnn_recurrence_accuracy: 0.8340 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 2.4335e-05
# Epoch 32/50
# 400/400 [==============================] - 199s 497ms/step - loss: 1.5299 - rcnn_recurrence_accuracy: 0.8340 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 1.5818e-05
# Epoch 33/50
# 400/400 [==============================] - 200s 500ms/step - loss: 1.5298 - rcnn_recurrence_accuracy: 0.8340 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 1.0282e-05
# Epoch 34/50
# 400/400 [==============================] - 198s 496ms/step - loss: 1.5298 - rcnn_recurrence_accuracy: 0.8340 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 6.6831e-06
# Epoch 35/50
# 400/400 [==============================] - 196s 491ms/step - loss: 1.5298 - rcnn_recurrence_accuracy: 0.8341 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 4.3440e-06
# Epoch 36/50
# 400/400 [==============================] - 198s 496ms/step - loss: 1.5298 - rcnn_recurrence_accuracy: 0.8341 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 2.8236e-06
# Epoch 37/50
# 400/400 [==============================] - 198s 495ms/step - loss: 1.5297 - rcnn_recurrence_accuracy: 0.8341 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 1.8353e-06
# Epoch 38/50
# 400/400 [==============================] - 202s 504ms/step - loss: 1.5297 - rcnn_recurrence_accuracy: 0.8341 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 1.1930e-06
# Epoch 39/50
# 400/400 [==============================] - 199s 496ms/step - loss: 1.5297 - rcnn_recurrence_accuracy: 0.8341 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 7.7543e-07
# Epoch 40/50
# 400/400 [==============================] - 199s 497ms/step - loss: 1.5297 - rcnn_recurrence_accuracy: 0.8341 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 5.0403e-07
# Epoch 41/50
# 400/400 [==============================] - 200s 501ms/step - loss: 1.5297 - rcnn_recurrence_accuracy: 0.8341 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 3.2762e-07
# Epoch 42/50
# 400/400 [==============================] - 200s 500ms/step - loss: 1.5297 - rcnn_recurrence_accuracy: 0.8341 - val_loss: 1.5431 - val_rcnn_recurrence_accuracy: 0.8312 - lr: 2.1295e-07
# 500/500 [==============================] - 145s 206ms/step
# Inaccuracy of the final model on the test data: [0.1406852 0.1649396 0.1904142 0.2209008 0.1639218]

# %%
pymatcher = pymatching.Matching.from_detector_error_model(detector_error_model)
flips_pred_pym = pymatcher.decode_batch(det_evts, bit_packed_predictions=False, bit_packed_shots=False).astype(binary_t).reshape(-1,1)
print(f"PyMatching error rate for the full data set: {np.mean((flips_pred_pym!=flips[:,-1:]))}")
flips_pred_pym = pymatcher.decode_batch(det_evts[idxs_test,:], bit_packed_predictions=False, bit_packed_shots=False).astype(binary_t).reshape(-1,1)
print(f"PyMatching error rate for test data set: {np.mean((flips_pred_pym!=flips[idxs_test,-1:]))}")
# Out:
# PyMatching error rate for the full data set: 0.0838103
# PyMatching error rate for test data set: 0.0838664

# %%
# Plot the training history
# Left panel: loss, right panel: accuracy

fig, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].plot(history.history['loss'], label='Train')
ax[0].plot(history.history['val_loss'], label='Validation')
ax[0].set_title('Model loss')
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Epoch')
ax[0].set_ylim([1.5, 1.8])
ax[0].legend()

frate = np.mean((flips_pred_pym!=flips[idxs_test,-1:]))
ftest = np.mean((class_bits[idxs_test]!=(flips_pred>0.5).astype(binary_t)).astype(binary_t), axis=0)
ax[1].plot([1.-x for x in history.history['rcnn_recurrence_accuracy']], label='Train')
ax[1].plot([1.-x for x in history.history['val_rcnn_recurrence_accuracy']], label='Validation')
ax[1].plot([0, history.epoch[-1]], [ftest]*2, label='Test', linestyle="--")
ax[1].plot([0, history.epoch[-1]], [frate]*2, label='PyMatching')
ax[1].set_title('Model inaccuracy')
ax[1].set_ylabel('Inaccuracy')
ax[1].set_xlabel('Epoch')
ax[1].set_ylim([0.08, 0.275])
ax[1].legend()

fig.set_dpi(120)
plt.show()

# %%
model_dxd.save_weights(f"{saved_data_dir}/model_dxd", overwrite=True)
save_history(history, f"{saved_data_dir}/history.root")
